# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit4352/COVID19-analysis-Jan-Apr/blob/master/covid19_analysis_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # $$\textrm{Covid19 Data Analysis Notebook}$$
# ------------------------------------------

# %% [markdown]
# # Import the libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Importing dataset Covid19_Confirmed_dataset

# %%
corona_df = pd.read_csv('covid19_Confirmed_dataset.csv')
corona_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan  33.0000  ...     1828     1939     2171
# 1            NaN        Albania  41.1533  ...      750      766      773
# 2            NaN        Algeria  28.0339  ...     3649     3848     4006
# 3            NaN        Andorra  42.5063  ...      743      743      745
# 4            NaN         Angola -11.2027  ...       27       27       27
#
# [5 rows x 104 columns]

# %%
corona_df.nunique()
# Out:
# Province/State     82
# Country/Region    187
# Lat               256
# Long              259
# 1/22/20            11
#                  ...
# 4/26/20           227
# 4/27/20           228
# 4/28/20           229
# 4/29/20           232
# 4/30/20           227
# Length: 104, dtype: int64

# %%
corona_df.shape
# Out:
# (266, 104)

# %% [markdown]
# ## Drop the useless columns

# %% [markdown]
# > Lat and longitude is not usefull

# %%
cor_df = corona_df.drop(["Lat","Long"],axis=1)

# %%
cor_df.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan        0  ...     1828     1939     2171
# 1            NaN        Albania        0  ...      750      766      773
# 2            NaN        Algeria        0  ...     3649     3848     4006
# 3            NaN        Andorra        0  ...      743      743      745
# 4            NaN         Angola        0  ...       27       27       27
#
# [5 rows x 102 columns]

# %% [markdown]
# > Aggregating the rows by the country

# %%
cor_df_agg = cor_df.groupby("Country/Region").sum()

# %%
cor_df_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1828     1939     2171
# Albania               0        0        0  ...      750      766      773
# Algeria               0        0        0  ...     3649     3848     4006
# Andorra               0        0        0  ...      743      743      745
# Angola                0        0        0  ...       27       27       27
#
# [5 rows x 100 columns]

# %%
cor_df_agg.shape
# Out:
# (187, 100)

# %%
cor_df_agg.index.unique()
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'United Kingdom', 'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country/Region', length=187)

# %% [markdown]
# ## Visualizing data related to a country
# visualization always helps for better understanding of our data.

# %%
cor_df_agg.loc["India"].plot()
cor_df_agg.loc["China"].plot()
cor_df_agg.loc["Italy"].plot()

plt.legend()

# %% [markdown]
# ## Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %% [markdown]
# > spread in three days

# %%
cor_df_agg.loc["China"][:3].plot()

# %% [markdown]
# ## caculating the first derivative of the curve

# %%
cor_df_agg.loc["China"].diff().plot()

# %% [markdown]
# ## Find maxmimum infection rate for China

# %%
cor_df_agg.loc["China"].diff().max()
# Out:
# 15136.0

# %% [markdown]
# ## Find maximum infection rate for all of the countries.

# %%
countries = list(cor_df_agg.index)
max_rates = []
for c in countries:
    max_rates.append(cor_df_agg.loc[c].diff().max())
    
cor_df_agg["Max_infect_rate"] = max_rates

# %%
cor_df_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  Max_infect_rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1939     2171            232.0
# Albania               0        0        0  ...      766      773             34.0
# Algeria               0        0        0  ...     3848     4006            199.0
# Andorra               0        0        0  ...      743      745             43.0
# Angola                0        0        0  ...       27       27              5.0
#
# [5 rows x 101 columns]

# %% [markdown]
# Create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(cor_df_agg["Max_infect_rate"])
corona_data.head()
# Out:
#                 Max_infect_rate
# Country/Region
# Afghanistan               232.0
# Albania                    34.0
# Algeria                   199.0
# Andorra                    43.0
# Angola                      5.0

# %% [markdown]
# > **Max infected coutries**

# %%
d1 = corona_data.sort_values(['Max_infect_rate'], ascending=False).head(15)
dd1 = d1.style.background_gradient(subset = ['Max_infect_rate'], cmap = 'PuBu')
dd1
# Out:
# <style  type="text/css" >
#     #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row1_col0 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row2_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row3_col0 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row4_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row5_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_de70a6d4_ea0e_11ea_aabe_0242ac1c0002row6_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
# ...

# %%
df1 = corona_data.sort_values("Max_infect_rate", axis = 0, ascending = False) 
df1 = df1.head(10)
plot = df1.plot.pie(subplots=True, autopct='%1.1f%%', figsize=(10, 10))

# %% [markdown]
# # Import the happiness report and join:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ## Task 1 : Importing the dataset

# %%
world_happy_df = pd.read_csv("worldwide_happiness_report.csv", index_col="Overall rank")
world_happy_df.head()
# Out:
#              Country or region  Score  ...  Generosity  Perceptions of corruption
# Overall rank                           ...
# 1                      Finland  7.769  ...       0.153                      0.393
# 2                      Denmark  7.600  ...       0.252                      0.410
# 3                       Norway  7.554  ...       0.271                      0.341
# 4                      Iceland  7.494  ...       0.354                      0.118
# 5                  Netherlands  7.488  ...       0.322                      0.298
#
# [5 rows x 8 columns]

# %%
world_happy_df.describe()
# Out:
#             Score  GDP per capita  ...  Generosity  Perceptions of corruption
# count  156.000000      156.000000  ...  156.000000                 156.000000
# mean     5.407096        0.905147  ...    0.184846                   0.110603
# std      1.113120        0.398389  ...    0.095254                   0.094538
# min      2.853000        0.000000  ...    0.000000                   0.000000
# 25%      4.544500        0.602750  ...    0.108750                   0.047000
# 50%      5.379500        0.960000  ...    0.177500                   0.085500
# 75%      6.184500        1.232500  ...    0.248250                   0.141250
# max      7.769000        1.684000  ...    0.566000                   0.453000
#
# [8 rows x 7 columns]

# %%
sns.pairplot(world_happy_df);

# %% [markdown]
# ## Task 2: let's drop the useless columns

# %%
drop_cols = ["Score", "Generosity", "Perceptions of corruption"]

# %%
world_happy_df.drop(drop_cols, axis=1,inplace=True)
world_happy_df.head()
# Out:
#              Country or region  ...  Freedom to make life choices
# Overall rank                    ...
# 1                      Finland  ...                         0.596
# 2                      Denmark  ...                         0.592
# 3                       Norway  ...                         0.603
# 4                      Iceland  ...                         0.591
# 5                  Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Task 3: changing the indices of the dataframe

# %%
world_happy_df.set_index("Country or region",inplace=True)

# %%
world_happy_df.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Task 4: Join two dataset we have prepared

# %% [markdown]
# ### Corona Dataset :

# %%
corona_data.head()
# Out:
#                 Max_infect_rate
# Country/Region
# Afghanistan               232.0
# Albania                    34.0
# Algeria                   199.0
# Andorra                    43.0
# Angola                      5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# ### wolrd happiness report Dataset :

# %%
world_happy_df.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
world_happy_df.shape
# Out:
# (156, 4)

# %%
joined_df = corona_data.join(world_happy_df,how="inner")
joined_df.head()
# Out:
#              Max_infect_rate  ...  Freedom to make life choices
# Afghanistan            232.0  ...                         0.000
# Albania                 34.0  ...                         0.383
# Algeria                199.0  ...                         0.086
# Argentina              291.0  ...                         0.471
# Armenia                134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Task 5: correlation matrix

# %%
matrix = joined_df.corr()
plt.figure(figsize=(8,6))
#plot heat map
g=sns.heatmap(matrix,annot=True,cmap="YlGn_r")

# %% [markdown]
# ## Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
joined_df.head()
# Out:
#              Max_infect_rate  ...  Freedom to make life choices
# Afghanistan            232.0  ...                         0.000
# Albania                 34.0  ...                         0.383
# Algeria                199.0  ...                         0.086
# Argentina              291.0  ...                         0.471
# Armenia                134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = joined_df["GDP per capita"]
y = joined_df["Max_infect_rate"]
sns.regplot(x,np.log(y))

# %% [markdown]
# > GDP has positive correltion with the infection rate

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = joined_df["Social support"]
y = joined_df["Max_infect_rate"]
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = joined_df["Healthy life expectancy"]
y = joined_df["Max_infect_rate"]
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = joined_df["Freedom to make life choices"]
y = joined_df["Max_infect_rate"]
sns.regplot(x,np.log(y))

# %% [markdown]
# > **All the happiness factors shows that they positively affect infection rate**

# %% [markdown]
# ### Let's combine the plots

# %%
plt.figure(figsize=(14,10))
sns.regplot(np.log(joined_df["Max_infect_rate"]),joined_df["GDP per capita"],label="GDP")
sns.regplot(np.log(joined_df["Max_infect_rate"]),joined_df["Social support"],label="Social support")
sns.regplot(np.log(joined_df["Max_infect_rate"]),joined_df["Healthy life expectancy"],label="Life expectancy")
sns.regplot(np.log(joined_df["Max_infect_rate"]),joined_df["Freedom to make life choices"],label="Life choices")
plt.ylabel("dependencies")
plt.legend()

# %% [markdown]
# > Social Support has the highest contribution in infection rate
#
# > Than GDP of a country effects the rate and life choices effect the least

# %% [markdown]
# $$\textrm{Thank you for watching my notebook}$$
